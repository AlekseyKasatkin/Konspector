# %%
# !pip install plotly
# Out:
# ...
#   Obtaining dependency information for plotly from https://files.pythonhosted.org/packages/a8/07/72953cf70e3bd3a24cbc3e743e6f8539abe6e3e6d83c3c0c83426eaffd39/plotly-5.18.0-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for tenacity>=6.2.0 from https://files.pythonhosted.org/packages/f4/f1/990741d5bb2487d529d20a433210ffa136a367751e454214013b441c4575/tenacity-8.2.3-py3-none-any.whl.metadata
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.6/15.6 MB 6.7 MB/s eta 0:00:00m eta 0:00:010:00:01
# ...
#
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: pip install --upgrade pip

# %%
import pandas as pd
import numpy as np
import plotly.express as px

# %%
series = pd.Series(np.random.random(10))
series
# Out:
# 0    0.817219
# 1    0.365554
# 2    0.614022
# 3    0.261076
# 4    0.257730
# 5    0.019652
# 6    0.081692
# 7    0.612871
# 8    0.202365
# 9    0.477992
# dtype: float64

# %%
df = pd.read_csv('https://raw.githubusercontent.com/dayekb/mpti_ml/main/data/cars.csv',
                 delimiter = ',') # можно считывать открытые файлы из интернета

# %%
DF = df.drop_duplicates() # Складываем в новый DataFrame результат удаления дубликатов

DF = DF.reset_index(drop=True) # обновим индексы в DataFrame DF.
# если бы мы прописали drop = False, то была бы еще одна колонка - старые индексы

DF
# Out:
#              Make         Model  Year      Style  Distance  \
# 0          Toyota         Prius  2011  Hatchback  195000.0
# 1         Renault  Grand Scenic  2014  Universal  135000.0
# 2      Volkswagen          Golf  1998  Hatchback       1.0
# 3         Renault        Laguna  2012  Universal  110000.0
# 4            Opel         Astra  2006  Universal  200000.0
# ...           ...           ...   ...        ...       ...
# 37259  Land Rover    Freelander  2002  Crossover  225000.0
# 37260       Dacia     Logan Mcv  2015  Universal   89000.0
# 37261     Renault         Modus  2009  Hatchback     225.0
# 37262       Mazda             6  2006      Combi  370000.0
# 37263     Renault  Grand Scenic  2006    Minivan  300000.0
#
#        Engine_capacity(cm3)     Fuel_type Transmission  Price(euro)
# 0                    1800.0        Hybrid    Automatic       7750.0
# 1                    1500.0        Diesel       Manual       8550.0
# ...

# %%
import matplotlib.pyplot as plt # библиотека MatPlotLib для визуализации
import seaborn as sns # библиотека Seaborn для визуализации данных из Pandas

# %%
# рисуем с помощью библиотеки seaborn
sns.histplot(data=DF, # какой датафрейм используем
            x='Engine_capacity(cm3)', # какую переменную отрисовываем
            bins = 20);  # на сколько ячеек разбиваем

# %%
sns.pairplot(data = DF,  # какой датафрейм используем
             hue ='Transmission', # какую переменную используем для подкрашиваиния данных.
                                # Рекомендуется использовать Категориальные данные (не очень много уникальных значений)
             palette = 'bwr',); # какую цветовую карту используем. Здесь у нас всего 2 варианта, то мы используем bwr - один из Diverging
                                # если категорий больше, то лучше использовать что-то из Qualitative

# %%
fig, ax = plt.subplots(1, figsize=(15, 6))
sns.scatterplot(data=DF,
                x='Price(euro)', y='Year',
                hue='Transmission', alpha = 0.6,
                ax=ax)
plt.xscale("log")
plt.xlabel("Price (euro) - log scale");

# %%
fig, ax = plt.subplots(1, figsize=(15, 7))
sns.violinplot(data=DF,
               x="Fuel_type",  y='Price(euro)',
               hue="Transmission", split = True,
               ax=ax);

# %%
fig, ax = plt.subplots(1, figsize=(15, 7))
sns.countplot(data=DF, x="Year", hue="Transmission", ax=ax)
ax.tick_params(axis='x', rotation=90)

# %% [markdown]
# # Звдвние 2

# %%
Задание 2
0.0/4.0 points (graded)
Тема — Библиотека pandas. Извлечение базовых статистик
Набор данных Car Moldova после удаления дубликатов: https://raw.githubusercontent.com/dayekb/Basic_ML_Alg/main/cars_moldova_no_dup.csv.

Подготовьте ответы на следующие вопросы.

1. Сколько строк в наборе данных?

  нет ответа 
 
2. Укажите медианное значение столбца с объемом двигателя (Engine_capacity(cm3)). В ответе укажите целую часть.

  нет ответа 
 
3. Укажите наиболее часто встречающийся тип топлива (Fuel_type) и число таких автомобилей. В первом ответе укажите строку без кавычек.

# %%
import pandas as pd

# %%
df = pd.read_csv('https://raw.githubusercontent.com/dayekb/Basic_ML_Alg/main/cars_moldova_no_dup.csv')
df
# Out:
#              Make         Model  Year      Style  Distance  \
# 0          Toyota         Prius  2011  Hatchback  195000.0
# 1         Renault  Grand Scenic  2014  Universal  135000.0
# 2      Volkswagen          Golf  1998  Hatchback       1.0
# 3         Renault        Laguna  2012  Universal  110000.0
# 4            Opel         Astra  2006  Universal  200000.0
# ...           ...           ...   ...        ...       ...
# 37259  Land Rover    Freelander  2002  Crossover  225000.0
# 37260       Dacia     Logan Mcv  2015  Universal   89000.0
# 37261     Renault         Modus  2009  Hatchback     225.0
# 37262       Mazda             6  2006      Combi  370000.0
# 37263     Renault  Grand Scenic  2006    Minivan  300000.0
#
#        Engine_capacity(cm3)     Fuel_type Transmission  Price(euro)
# 0                    1800.0        Hybrid    Automatic       7750.0
# 1                    1500.0        Diesel       Manual       8550.0
# ...

# %%
# 1. Сколько строк в наборе данных?
37264

# %%
# 2. Укажите медианное значение столбца с объемом двигателя (Engine_capacity(cm3)). В ответе укажите целую часть.
df['Engine_capacity(cm3)'].median()
# Out:
# 1800.0

# %%
# 3. Укажите наиболее часто встречающийся тип топлива (Fuel_type) и число таких автомобилей. 
# В первом ответе укажите строку без кавычек.
df.groupby('Fuel_type').count()
# Out:
#                  Make  Model   Year  Style  Distance  Engine_capacity(cm3)  \
# Fuel_type
# Diesel          17198  17198  17198  17198     17198                 17198
# Electric          282    282    282    282       282                   282
# Hybrid           1976   1976   1976   1976      1976                  1976
# Metan/Propan     4169   4169   4169   4169      4169                  4169
# Petrol          13175  13175  13175  13175     13175                 13175
# Plug-in Hybrid    464    464    464    464       464                   464
#
#                 Transmission  Price(euro)
# Fuel_type
# Diesel                 17198        17198
# Electric                 282          282
# Hybrid                  1976         1976
# Metan/Propan            4169         4169
# Petrol                 13175        13175
# Plug-in Hybrid           464          464

# %% [markdown]
# # Задание 3

# %% [markdown]
# 2/2 points (graded)
# Тема — Библиотека pandas. Логическая индексация
# Набор данных Car Moldova после удаления дубликатов: https://raw.githubusercontent.com/dayekb/Basic_ML_Alg/main/cars_moldova_no_dup.csv.
#
# Подготовьте ответы на следующие вопросы.
#
# 1. Укажите количество автомобилей, для которых тип кузова — Universal (столбец Style) и стоимость выше 10000 евро (столбец Price(euro)).
#
# 868
#   верно
#
# 2. Укажите количество автомобилей, для которых марка автомобиля — Mercedes (столбец Make) и год выпуска — раньше 1980 года (столбец Year).
#
# 6
#   верно

# %%
df[df['Price(euro)']>10000]
# Out:
#              Make      Model  Year      Style  Distance  Engine_capacity(cm3)  \
# 7      Volkswagen    Touareg  2010        SUV  220000.0                2400.0
# 10       Mercedes    E Class  2010      Sedan  210000.0                2200.0
# 11       Mercedes  CLS Class  2006      Coupe  300000.0                3200.0
# 16          Volvo       XC60  2012  Crossover  180000.0                2400.0
# 23          Tesla    Model S  2013  Hatchback  113000.0                 367.0
# ...           ...        ...   ...        ...       ...                   ...
# 37236        Ford     Mondeo  2016      Sedan   83400.0                1500.0
# 37240         KIA   Sportage  2011        SUV  122000.0                2000.0
# 37248  Volkswagen     Passat  2016  Universal  180000.0                1800.0
# 37257       Skoda     Superb  2016  Cabriolet   78900.0                2000.0
# 37258  Volkswagen     Passat  2016      Sedan   88000.0                1800.0
#
# ...

# %%
df[(df['Style']=='Universal') & (df['Price(euro)']>10000)].count()
# Out:
# Make                    868
# Model                   868
# Year                    868
# Style                   868
# Distance                868
# Engine_capacity(cm3)    868
# Fuel_type               868
# Transmission            868
# Price(euro)             868
# dtype: int64

# %% [markdown]
# ## 2.2 Укажите количество автомобилей, для которых марка автомобиля — Mercedes (столбец Make) и год выпуска — раньше 1980 года (столбец Year).

# %%
df[(df['Make']=='Mercedes')& (df['Year']<1980)].count()
# Out:
# Make                    6
# Model                   6
# Year                    6
# Style                   6
# Distance                6
# Engine_capacity(cm3)    6
# Fuel_type               6
# Transmission            6
# Price(euro)             6
# dtype: int64

# %% [markdown]
# # Задание 4

# %%
0.0/3.0 points (graded)
Тема — Библиотека pandas. Агрегация
Набор данных Car Moldova после удаления дубликатов: https://raw.githubusercontent.com/dayekb/Basic_ML_Alg/main/cars_moldova_no_dup.csv.

Подготовьте ответы на следующие вопросы.

Для решения этого задания вам необходимо воспользоваться методами groupby для агрегации данных, sort_values для сортировки таблицы.

1. Найдите марку автомобилей (столбец Make) с наибольшей средней стоимостью (столбец Price(euro))

  нет ответа 
2. Найдите модель автомобилей (столбец Model) с наибольшим средним пробегом (столбец Distance).

  нет ответа 
 
3. Найдите тип топлива (столбец Fuel_type) с наибольшим средним годом выпуска (столбец Year).

# %%
df[['Make', 'Price(euro)']].groupby('Make').agg(max).sort_values('Price(euro)', ascending= False)[:1]
# Out:
# /tmp/ipykernel_23132/1402973947.py:1: FutureWarning:
#
# The provided callable <built-in function max> is currently using DataFrameGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#             Price(euro)
# Make
# Brilliance   10000000.0

# %%
df[['Model', 'Distance']].groupby('Model').agg(max).sort_values('Distance', ascending= False)
# Out:
# /tmp/ipykernel_23132/3456840887.py:1: FutureWarning:
#
# The provided callable <built-in function max> is currently using DataFrameGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#            Distance
# Model
# 2108    100000000.0
# Vito    100000000.0
# Vectra  100000000.0
# Golf    100000000.0
# 2109    100000000.0
# ...             ...
# Poer            0.0
# H6              0.0
# H9              0.0
# G3              0.0
# D50             0.0
#
# [829 rows x 1 columns]

# %%
df[['Fuel_type', 'Year']].groupby('Fuel_type').agg(min).sort_values('Year', ascending= True)
# Out:
# /tmp/ipykernel_23132/2005618.py:1: FutureWarning:
#
# The provided callable <built-in function min> is currently using DataFrameGroupBy.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#                 Year
# Fuel_type
# Diesel          1900
# Electric        1900
# Hybrid          1900
# Metan/Propan    1900
# Petrol          1900
# Plug-in Hybrid  2002
